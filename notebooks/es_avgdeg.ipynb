# %% [markdown]
# # Edge sampling - average degree

# %%
stats_folder="~/networkgrowth/stats/"

# %%
# %matplotlib inline
import sys
sys.path.insert(0,"../python")
from plot.plot import Plot
from plot.network_growth_parser import Parser
from plot.network_growth import NetworkGrowth
from plot.avg_deg_fit import AvgDegFit

# %%
Plot().set(2.5)
parser = Parser()
data = parser.run(stats_folder)

# %%
network_growth = NetworkGrowth(data)
network_growth.run()

# %%
fit = AvgDegFit(data)
fit.plot()
# Out:
# ../python/plot/avg_deg_fit.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.data[d][1]["log_n"] = np.log(self.data[d][1]["node_num"])/np.log(10)
# ../python/plot/avg_deg_fit.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.data[d][1]["ln_n"] = np.log(self.data[d][1]["node_num"])
# oc [ 0.75625591  0.29561836 -2.05069409]
# 15 [ 0.73130432  0.24517242 -1.14457931]
# mh [ 0.35209727  0.19973745 -1.26632421]
# fb [ 1.18819681  1.23027485 -9.87934492]
# db [ 0.91658174  0.27002975 -2.16952768]
# wi [ 1.42167556  0.6929375  -5.99495689]
