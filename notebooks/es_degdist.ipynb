# %% [markdown]
# # Edge sampling - degree distribution and the average degree
#
# * We connect the growth of the average degree to the evolving power-law degree distribution exponent.
#   * Plots on the left: Comparison of average degree values. The red curve corresponds to the actual average degree. The scatter plots are values computed from the exponent estimates.
#   * Plots on the right: Comparison of estimates of Delta. The red curve corresponds to an approximation based the average degree.

# %%
stats_folder="~/networkgrowth/stats/"

# %%
# %matplotlib inline
import sys
sys.path.insert(0,"../python")
from plot.plot import Plot
from plot.network_growth_parser import Parser
from plot.deg_delta import DegDelta
from plot.nonzero import NonZero

# %%
Plot().set(2.4)
parser = Parser()
data = parser.run(stats_folder)

# %%
n = NonZero(data)
n.run()

# %%
degdelta = DegDelta(data)
degdelta.run()
