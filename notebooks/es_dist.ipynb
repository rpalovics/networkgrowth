# %% [markdown]
# # Evolving power-law degree distributions
#
# * Evolving degree distributions for eight edge sampled networks are shown
# * For each dataset, the degree distribution is plotted at sizes 32,64,128,...
# * Distributions are shown on log-log scale

# %%
stats_folder="~/networkgrowth/stats/"

# %%
# %matplotlib inline
import sys
sys.path.insert(0,"../python")
from plot.plot import Plot
from plot.dist import Dist
from plot.dist import DistParser
Plot().set(1.5)

# %%
parser = DistParser(stats_folder)
parser.run()
dist = Dist(parser.get())
dist.run()
