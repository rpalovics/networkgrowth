# %% [markdown]
# # Edge sampling - randomization
# * Result of shuffling the events in the time series
# * The original graph is always denser than the randomized one
# * The final average degree is always the same in the two timeseries.
# * We show the average degree at 2^i, i = 4,5,... sizes, therefore the figures not include the very last average degree for the final graphs

# %%
stats_folder="~/networkgrowth/stats/"

# %%
# %matplotlib inline
import sys
sys.path.insert(0,"../python")
from plot.plot import Plot
from plot.network_growth_parser import Parser
from plot.swap_edge import SwapEdge

# %%
Plot().set(1.5)
parser = Parser()
data = parser.run(stats_folder)
swap_edge= SwapEdge(data)
swap_edge.run()
